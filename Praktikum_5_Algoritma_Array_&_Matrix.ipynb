# %% [markdown]
# <a href="https://colab.research.google.com/github/Bariqnabilrahman/Projek-Praktikum-Modul-1---Bariq-Nabil-Rahman/blob/main/Praktikum_5_Algoritma_Array_%26_Matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def input_matriks(baris, kolom, nama):
    print(f"\nMasukkan elemen matriks {nama} ({baris}x{kolom}):")
    matriks = []
    for i in range(baris):
        row = []
        for j in range(kolom):
            val = float(input(f"Elemen [{i+1},{j+1}]: "))
            row.append(val)
        matriks.append(row)
    return matriks

def print_matriks(matriks):
    for row in matriks:
        print("\t".join(f"{val:.2f}" for val in row))

def penjumlahan(A, B):
    hasil = []
    for i in range(len(A)):
        baris = []
        for j in range(len(A[0])):
            baris.append(A[i][j] + B[i][j])
        hasil.append(baris)
    return hasil

def perkalian(A, B):
    hasil = []
    for i in range(len(A)):
        baris = []
        for j in range(len(B[0])):
            total = 0
            for k in range(len(A[0])):
                total += A[i][k] * B[k][j]
            baris.append(total)
        hasil.append(baris)
    return hasil

def transpose(A):
    hasil = []
    for j in range(len(A[0])):
        baris = []
        for i in range(len(A)):
            baris.append(A[i][j])
        hasil.append(baris)
    return hasil

def kasus1():
    while True:
        print("\n=== MENU OPERASI (Kasus 1) ===")
        print("1. Penjumlahan Matriks")
        print("2. Perkalian Matriks")
        print("3. Transpose Matriks")
        print("4. Keluar")

        pilih = input("Pilih menu: ")

        if pilih == "4":
            break

        A = input_matriks(2, 2, "A")
        B = input_matriks(2, 2, "B")

        if pilih == "1":
            hasil = penjumlahan(A, B)
            print("\nHasil Penjumlahan A + B:")
            print_matriks(hasil)

        elif pilih == "2":
            hasil = perkalian(A, B)
            print("\nHasil Perkalian A x B:")
            print_matriks(hasil)

        elif pilih == "3":
            print("\nTranspose A:")
            print_matriks(transpose(A))
            print("Transpose B:")
            print_matriks(transpose(B))

        else:
            print("Pilihan tidak valid!")

kasus1()
# Out:
# === MENU OPERASI (Kasus 1) ===
# 1. Penjumlahan Matriks
# 2. Perkalian Matriks
# 3. Transpose Matriks
# 4. Keluar
# Pilih menu: 1
#
# Masukkan elemen matriks A (2x2):
# Elemen [1,1]: 1
# Elemen [1,2]: 2
# Elemen [2,1]: 1
# Elemen [2,2]: 2
#
# Masukkan elemen matriks B (2x2):
# Elemen [1,1]: 3
# Elemen [1,2]: 2
# Elemen [2,1]: 3
# Elemen [2,2]: 2
#
# Hasil Penjumlahan A + B:
# 4.00	4.00
# 4.00	4.00
#
# === MENU OPERASI (Kasus 1) ===
# 1. Penjumlahan Matriks
# 2. Perkalian Matriks
# 3. Transpose Matriks
# 4. Keluar
# Pilih menu: 2
#
# Masukkan elemen matriks A (2x2):
# Elemen [1,1]: 3
# Elemen [1,2]: 2
# Elemen [2,1]: 3
# Elemen [2,2]: 2
#
# Masukkan elemen matriks B (2x2):
# Elemen [1,1]: 5
# Elemen [1,2]: 1
# Elemen [2,1]: 5
# Elemen [2,2]: 1
#
# Hasil Perkalian A x B:
# 25.00	5.00
# 25.00	5.00
#
# === MENU OPERASI (Kasus 1) ===
# 1. Penjumlahan Matriks
# 2. Perkalian Matriks
# 3. Transpose Matriks
# 4. Keluar
# Pilih menu: 3
#
# Masukkan elemen matriks A (2x2):
# Elemen [1,1]: 6
# ...

# %%
def input_matriks(baris, kolom, nama):
    print(f"\nMasukkan elemen matriks {nama} ({baris}x{kolom}):")
    matriks = []
    for i in range(baris):
        row = []
        for j in range(kolom):
            val = float(input(f"Elemen [{i+1},{j+1}]: "))
            row.append(val)
        matriks.append(row)
    return matriks

def print_matriks(matriks):
    for row in matriks:
        print("\t".join(f"{val:.2f}" for val in row))

def penjumlahan(A, B):
    hasil = []
    for i in range(len(A)):
        baris = []
        for j in range(len(A[0])):
            baris.append(A[i][j] + B[i][j])
        hasil.append(baris)
    return hasil

def perkalian(A, B):
    hasil = []
    for i in range(len(A)):
        baris = []
        for j in range(len(B[0])):
            total = 0
            for k in range(len(A[0])):
                total += A[i][k] * B[k][j]
            baris.append(total)
        hasil.append(baris)
    return hasil

def transpose(A):
    hasil = []
    for j in range(len(A[0])):
        baris = []
        for i in range(len(A)):
            baris.append(A[i][j])
        hasil.append(baris)
    return hasil

def kasus2():
    while True:
        print("\n=== MENU OPERASI (Kasus 2) ===")
        print("1. Penjumlahan Matriks")
        print("2. Perkalian Matriks")
        print("3. Transpose Matriks")
        print("4. Keluar")

        pilih = input("Pilih menu: ")

        if pilih == "4":
            break

        A = input_matriks(2, 3, "A")
        B = input_matriks(3, 2, "B")

        if pilih == "1":
            print("\nPenjumlahan tidak dapat dilakukan karena ukuran berbeda!")

        elif pilih == "2":
            hasil = perkalian(A, B)
            print("\nHasil Perkalian A x B:")
            print_matriks(hasil)

        elif pilih == "3":
            print("\nTranspose A:")
            print_matriks(transpose(A))
            print("\nTranspose B:")
            print_matriks(transpose(B))

        else:
            print("Pilihan tidak valid!")

kasus2()
# Out:
# === MENU OPERASI (Kasus 2) ===
# 1. Penjumlahan Matriks
# 2. Perkalian Matriks
# 3. Transpose Matriks
# 4. Keluar
# Pilih menu: 1
#
# Masukkan elemen matriks A (2x3):
# Elemen [1,1]: 2
# Elemen [1,2]: 3
# Elemen [1,3]: 2
# Elemen [2,1]: 3
# Elemen [2,2]: 2
# Elemen [2,3]: 3
#
# Masukkan elemen matriks B (3x2):
# Elemen [1,1]: 4
# Elemen [1,2]: 1
# Elemen [2,1]:  4
# Elemen [2,2]: 1
# Elemen [3,1]: 4
# Elemen [3,2]: 1
#
# Penjumlahan tidak dapat dilakukan karena ukuran berbeda!
#
# === MENU OPERASI (Kasus 2) ===
# 1. Penjumlahan Matriks
# 2. Perkalian Matriks
# 3. Transpose Matriks
# 4. Keluar
# Pilih menu: 3
#
# Masukkan elemen matriks A (2x3):
# Elemen [1,1]: 3
# Elemen [1,2]: 2
# Elemen [1,3]: 3
# Elemen [2,1]: 2
# Elemen [2,2]: 3
# Elemen [2,3]: 2
#
# Masukkan elemen matriks B (3x2):
# Elemen [1,1]: 4
# Elemen [1,2]: 2
# Elemen [2,1]: 4
# Elemen [2,2]: 2
# Elemen [3,1]: 4
# Elemen [3,2]: 2
#
# Transpose A:
# 3.00	2.00
# 2.00	3.00
# 3.00	2.00
#
# Transpose B:
# 4.00	4.00	4.00
# ...

# %%
def input_matriks(baris, kolom, nama):
    print(f"\nMasukkan elemen matriks {nama} ({baris}x{kolom}):")
    matriks = []
    for i in range(baris):
        row = []
        for j in range(kolom):
            val = float(input(f"Elemen [{i+1},{j+1}]: "))
            row.append(val)
        matriks.append(row)
    return matriks

def print_matriks(matriks):
    for row in matriks:
        print("\t".join(f"{val:.2f}" for val in row))

def penjumlahan(A, B):
    hasil = []
    for i in range(len(A)):
        baris = []
        for j in range(len(A[0])):
            baris.append(A[i][j] + B[i][j])
        hasil.append(baris)
    return hasil

def perkalian(A, B):
    hasil = []
    for i in range(len(A)):
        baris = []
        for j in range(len(B[0])):
            total = 0
            for k in range(len(A[0])):
                total += A[i][k] * B[k][j]
            baris.append(total)
        hasil.append(baris)
    return hasil

def transpose(A):
    hasil = []
    for j in range(len(A[0])):
        baris = []
        for i in range(len(A)):
            baris.append(A[i][j])
        hasil.append(baris)
    return hasil

def kasus3():
    while True:
        print("\n=== MENU OPERASI (Kasus 3) ===")
        print("1. Penjumlahan Matriks")
        print("2. Perkalian Matriks")
        print("3. Transpose Matriks")
        print("4. Keluar")

        pilih = input("Pilih menu: ")

        if pilih == "4":
            break

        A = input_matriks(3, 3, "A")
        B = input_matriks(3, 3, "B")

        if pilih == "1":
            hasil = penjumlahan(A, B)
            print("\nHasil Penjumlahan A + B:")
            print_matriks(hasil)

        elif pilih == "2":
            hasil = perkalian(A, B)
            print("\nHasil Perkalian A x B:")
            print_matriks(hasil)

        elif pilih == "3":
            print("\nTranspose A:")
            print_matriks(transpose(A))
            print("\nTranspose B:")
            print_matriks(transpose(B))

        else:
            print("Pilihan tidak valid!")

kasus3()
# Out:
# === MENU OPERASI (Kasus 3) ===
# 1. Penjumlahan Matriks
# 2. Perkalian Matriks
# 3. Transpose Matriks
# 4. Keluar
# Pilih menu: 1
#
# Masukkan elemen matriks A (3x3):
# Elemen [1,1]: 2
# Elemen [1,2]: 3
# Elemen [1,3]: 2
# Elemen [2,1]: 3
# Elemen [2,2]: 2
# Elemen [2,3]: 3
# Elemen [3,1]: 5
# Elemen [3,2]: 4
# Elemen [3,3]: 7
#
# Masukkan elemen matriks B (3x3):
# Elemen [1,1]: 1
# Elemen [1,2]: 2
# Elemen [1,3]: 3
# Elemen [2,1]: 1
# Elemen [2,2]: 2
# Elemen [2,3]: 3
# Elemen [3,1]: 1
# Elemen [3,2]: 2
# Elemen [3,3]: 3
#
# Hasil Penjumlahan A + B:
# 3.00	5.00	5.00
# 4.00	4.00	6.00
# 6.00	6.00	10.00
#
# === MENU OPERASI (Kasus 3) ===
# 1. Penjumlahan Matriks
# 2. Perkalian Matriks
# 3. Transpose Matriks
# 4. Keluar
# Pilih menu: 3
#
# Masukkan elemen matriks A (3x3):
# Elemen [1,1]: 1
# Elemen [1,2]: 2
# Elemen [1,3]: 3
# Elemen [2,1]: 1
# Elemen [2,2]: 2
# Elemen [2,3]: 3
# Elemen [3,1]: 1
# Elemen [3,2]: 2
# Elemen [3,3]: 3
#
# Masukkan elemen matriks B (3x3):
# Elemen [1,1]: 3
# ...

# %%
def input_matriks(baris, kolom, nama):
    print(f"\nMasukkan elemen matriks {nama} ({baris}x{kolom}):")
    matriks = []
    for i in range(baris):
        row = []
        for j in range(kolom):
            val = float(input(f"Elemen [{i+1},{j+1}]: "))
            row.append(val)
        matriks.append(row)
    return matriks

def print_matriks(matriks):
    for row in matriks:
        print("\t".join(f"{val:.2f}" for val in row))

def penjumlahan(A, B):
    hasil = []
    for i in range(len(A)):
        baris = []
        for j in range(len(A[0])):
            baris.append(A[i][j] + B[i][j])
        hasil.append(baris)
    return hasil

def perkalian(A, B):
    hasil = []
    for i in range(len(A)):
        baris = []
        for j in range(len(B[0])):
            total = 0
            for k in range(len(A[0])):
                total += A[i][k] * B[k][j]
            baris.append(total)
        hasil.append(baris)
    return hasil

def transpose(A):
    hasil = []
    for j in range(len(A[0])):
        baris = []
        for i in range(len(A)):
            baris.append(A[i][j])
        hasil.append(baris)
    return hasil

def kasus4():
    while True:
        print("\n=== MENU OPERASI (Kasus 4) ===")
        print("1. Penjumlahan Matriks")
        print("2. Perkalian Matriks")
        print("3. Transpose Matriks")
        print("4. Keluar")

        pilih = input("Pilih menu: ")

        if pilih == "4":
            break

        A = input_matriks(3, 2, "A")
        B = input_matriks(3, 2, "B")

        if pilih == "1":
            hasil = penjumlahan(A, B)
            print("\nHasil Penjumlahan A + B:")
            print_matriks(hasil)

        elif pilih == "2":
            print("\nPerkalian tidak bisa dilakukan karena ukuran tidak sesuai!")

        elif pilih == "3":
            print("\nTranspose A:")
            print_matriks(transpose(A))
            print("\nTranspose B:")
            print_matriks(transpose(B))

        else:
            print("Pilihan tidak valid!")

kasus4()
# Out:
# === MENU OPERASI (Kasus 4) ===
# 1. Penjumlahan Matriks
# 2. Perkalian Matriks
# 3. Transpose Matriks
# 4. Keluar
# Pilih menu: 1
#
# Masukkan elemen matriks A (3x2):
# Elemen [1,1]: 7
# Elemen [1,2]: 6
# Elemen [2,1]: 7
# Elemen [2,2]: 6
# Elemen [3,1]: 7
# Elemen [3,2]: 6
#
# Masukkan elemen matriks B (3x2):
# Elemen [1,1]: 7
# Elemen [1,2]: 8
# Elemen [2,1]: 7
# Elemen [2,2]: 8
# Elemen [3,1]: 7
# Elemen [3,2]: 8
#
# Hasil Penjumlahan A + B:
# 14.00	14.00
# 14.00	14.00
# 14.00	14.00
#
# === MENU OPERASI (Kasus 4) ===
# 1. Penjumlahan Matriks
# 2. Perkalian Matriks
# 3. Transpose Matriks
# 4. Keluar
# Pilih menu: 2
#
# Masukkan elemen matriks A (3x2):
# Elemen [1,1]: 3
# Elemen [1,2]: 2
# Elemen [2,1]: 3
# Elemen [2,2]: 2
# Elemen [3,1]: 3
# Elemen [3,2]: 2
#
# Masukkan elemen matriks B (3x2):
# Elemen [1,1]: 6
# Elemen [1,2]: 5
# Elemen [2,1]: 6
# Elemen [2,2]: 5
# Elemen [3,1]: 6
# Elemen [3,2]: 5
#
# Perkalian tidak bisa dilakukan karena ukuran tidak sesuai!
#
# ...
